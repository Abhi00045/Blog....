# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder
# Ignore all warnings
warnings.filterwarnings('ignore')
import os
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC,SVR
import joblib
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"Malaria.csv")
df
# Out:
#      temp_level humidity precipitation frequency_outbreak_in_area  \
# 0           Low     High           Yes                       High
# 1          High      Low            No                       High
# 2          High     High           Yes                        Low
# 3          High      Low           Yes                        Low
# 4           Low     High           Yes                       High
# ...         ...      ...           ...                        ...
# 7995       High      Low            No                        Low
# 7996        Low     High           Yes                        Low
# 7997       High     High            No                        Low
# 7998        Low     High            No                       High
# 7999       High     High           Yes                       High
#
#      travel_patterns        mosquito_species malaria_vectors  \
# 0                Low           Aedes aegypti              No
# 1               High       Anopheles gambiae              No
# 2               High  Culex quinquefasciatus              No
# 3                Low       Anopheles gambiae             Yes
# 4                Low           Aedes aegypti             Yes
# ...              ...                     ...             ...
# 7995             Low           Aedes aegypti              No
# 7996             Low       Anopheles gambiae              No
# 7997            High       Anopheles gambiae             Yes
# 7998            High  Culex quinquefasciatus             Yes
# 7999             Low           Aedes aegypti              No
#
#      vectors_infection_rates healthcare_availability healthcare_accessibility  \
# 0                        Low                     Yes                       No
# 1                       High                     Yes                      Yes
# 2                        Low                     Yes                      Yes
# 3                        Low                      No                      Yes
# 4                        Low                      No                      Yes
# ...                      ...                     ...                      ...
# 7995                     Low                      No                       No
# 7996                    High                      No                      Yes
# 7997                    High                     Yes                      Yes
# 7998                     Low                     Yes                       No
# 7999                     Low                     Yes                       No
#
#      malaria_treatment_success_rates land_use mosquito_breeding_sites  \
# 0                                Low    Urban                      No
# 1                               High    Urban                     Yes
# 2                               High    Urban                     Yes
# 3                                Low    Rural                     Yes
# 4                                Low    Urban                      No
# ...                              ...      ...                     ...
# 7995                             Low    Urban                      No
# 7996                             Low    Rural                      No
# 7997                             Low    Rural                     Yes
# 7998                            High    Urban                     Yes
# 7999                            High    Rural                     Yes
#
#      stagnant_waters iot_air_quality iot_water_quality presence_of_vegetation  \
# 0                Yes             Bad              Good                    Yes
# 1                Yes             Bad               Bad                    Yes
# 2                Yes             Bad              Good                     No
# 3                Yes            Good              Good                    Yes
# 4                Yes             Bad              Good                     No
# ...              ...             ...               ...                    ...
# 7995             Yes            Good               Bad                     No
# 7996              No             Bad               Bad                    Yes
# 7997              No             Bad              Good                     No
# 7998             Yes            Good               Bad                    Yes
# 7999             Yes             Bad              Good                     No
#
#       outbreak_threshold
# 0               0.487875
# 1               0.019257
# 2               0.978092
# 3               0.858584
# 4               0.344199
# ...                  ...
# 7995            0.730745
# 7996            0.176349
# 7997            0.549012
# 7998            0.993842
# 7999            0.477947
#
# [8000 rows x 18 columns]

# %%
from sklearn.utils import resample

df = resample(df, replace=True, n_samples=39000, random_state=42)

# %%
df.head()
# Out:
#      temp_level humidity precipitation frequency_outbreak_in_area  \
# 7270        Low      Low           Yes                       High
# 7603       High      Low            No                       High
# 860        High      Low           Yes                        Low
# 5390        Low     High            No                        Low
# 5226        Low     High            No                       High
#
#      travel_patterns        mosquito_species malaria_vectors  \
# 7270             Low       Anopheles gambiae              No
# 7603            High  Culex quinquefasciatus             Yes
# 860             High       Anopheles gambiae              No
# 5390             Low           Aedes aegypti              No
# 5226            High       Anopheles gambiae             Yes
#
#      vectors_infection_rates healthcare_availability healthcare_accessibility  \
# 7270                    High                      No                       No
# 7603                    High                      No                       No
# 860                     High                      No                      Yes
# 5390                     Low                     Yes                       No
# 5226                    High                      No                      Yes
#
#      malaria_treatment_success_rates land_use mosquito_breeding_sites  \
# 7270                            High    Urban                     Yes
# 7603                            High    Urban                     Yes
# 860                              Low    Urban                     Yes
# 5390                             Low    Rural                     Yes
# 5226                             Low    Rural                     Yes
#
#      stagnant_waters iot_air_quality iot_water_quality presence_of_vegetation  \
# 7270              No             Bad              Good                     No
# 7603              No             Bad               Bad                    Yes
# 860              Yes            Good               Bad                     No
# 5390             Yes            Good               Bad                     No
# 5226              No            Good               Bad                     No
#
#       outbreak_threshold
# 7270            0.668590
# 7603            0.746953
# 860             0.732301
# 5390            0.097194
# 5226            0.621262

# %%
y=df['outbreak_threshold']

# %%
import pandas as pd

# Check the data types of each column
print(df.dtypes)
# Out:
# temp_level                          object
# humidity                            object
# precipitation                       object
# frequency_outbreak_in_area          object
# travel_patterns                     object
# mosquito_species                    object
# malaria_vectors                     object
# vectors_infection_rates             object
# healthcare_availability             object
# healthcare_accessibility            object
# malaria_treatment_success_rates     object
# land_use                            object
# mosquito_breeding_sites             object
# stagnant_waters                     object
# iot_air_quality                     object
# iot_water_quality                   object
# presence_of_vegetation              object
# outbreak_threshold                 float64
# dtype: object

# %%
print(df.dtypes)
# Out:
# temp_level                          object
# humidity                            object
# precipitation                       object
# frequency_outbreak_in_area          object
# travel_patterns                     object
# mosquito_species                    object
# malaria_vectors                     object
# vectors_infection_rates             object
# healthcare_availability             object
# healthcare_accessibility            object
# malaria_treatment_success_rates     object
# land_use                            object
# mosquito_breeding_sites             object
# stagnant_waters                     object
# iot_air_quality                     object
# iot_water_quality                   object
# presence_of_vegetation              object
# outbreak_threshold                 float64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['mosquito_species'].unique()
# Out:
# array(['Anopheles gambiae', 'Culex quinquefasciatus', 'Aedes aegypti'],
#       dtype=object)

# %%
## null 

df.isnull().sum()
# Out:
# temp_level                         0
# humidity                           0
# precipitation                      0
# frequency_outbreak_in_area         0
# travel_patterns                    0
# mosquito_species                   0
# malaria_vectors                    0
# vectors_infection_rates            0
# healthcare_availability            0
# healthcare_accessibility           0
# malaria_treatment_success_rates    0
# land_use                           0
# mosquito_breeding_sites            0
# stagnant_waters                    0
# iot_air_quality                    0
# iot_water_quality                  0
# presence_of_vegetation             0
# outbreak_threshold                 0
# dtype: int64

# %%
df.head(2)
# Out:
#      temp_level humidity precipitation frequency_outbreak_in_area  \
# 7270        Low      Low           Yes                       High
# 7603       High      Low            No                       High
#
#      travel_patterns        mosquito_species malaria_vectors  \
# 7270             Low       Anopheles gambiae              No
# 7603            High  Culex quinquefasciatus             Yes
#
#      vectors_infection_rates healthcare_availability healthcare_accessibility  \
# 7270                    High                      No                       No
# 7603                    High                      No                       No
#
#      malaria_treatment_success_rates land_use mosquito_breeding_sites  \
# 7270                            High    Urban                     Yes
# 7603                            High    Urban                     Yes
#
#      stagnant_waters iot_air_quality iot_water_quality presence_of_vegetation  \
# 7270              No             Bad              Good                     No
# 7603              No             Bad               Bad                    Yes
#
#       outbreak_threshold
# 7270            0.668590
# 7603            0.746953

# %% [markdown]
# ## LabelEncoder

# %%
# Initialize the LabelEncoder
le= LabelEncoder()

# Loop through each column in the DataFrame
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])
df.head()
# Out:
#       temp_level  humidity  precipitation  frequency_outbreak_in_area  \
# 7270           1         1              1                           0
# 7603           0         1              0                           0
# 860            0         1              1                           1
# 5390           1         0              0                           1
# 5226           1         0              0                           0
#
#       travel_patterns  mosquito_species  malaria_vectors  \
# 7270                1                 1                0
# 7603                0                 2                1
# 860                 0                 1                0
# 5390                1                 0                0
# 5226                0                 1                1
#
#       vectors_infection_rates  healthcare_availability  \
# 7270                        0                        0
# 7603                        0                        0
# 860                         0                        0
# 5390                        1                        1
# 5226                        0                        0
#
#       healthcare_accessibility  malaria_treatment_success_rates  land_use  \
# 7270                         0                                0         1
# 7603                         0                                0         1
# 860                          1                                1         1
# 5390                         0                                1         0
# 5226                         1                                1         0
#
#       mosquito_breeding_sites  stagnant_waters  iot_air_quality  \
# 7270                        1                0                0
# 7603                        1                0                0
# 860                         1                1                1
# 5390                        1                1                1
# 5226                        1                0                1
#
#       iot_water_quality  presence_of_vegetation  outbreak_threshold
# 7270                  1                       0            0.668590
# 7603                  0                       1            0.746953
# 860                   0                       0            0.732301
# 5390                  0                       0            0.097194
# 5226                  0                       0            0.621262

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39000 entries, 7270 to 4508
# Data columns (total 18 columns):
# temp_level                         39000 non-null int32
# humidity                           39000 non-null int32
# precipitation                      39000 non-null int32
# frequency_outbreak_in_area         39000 non-null int32
# travel_patterns                    39000 non-null int32
# mosquito_species                   39000 non-null int32
# malaria_vectors                    39000 non-null int32
# vectors_infection_rates            39000 non-null int32
# healthcare_availability            39000 non-null int32
# healthcare_accessibility           39000 non-null int32
# malaria_treatment_success_rates    39000 non-null int32
# land_use                           39000 non-null int32
# mosquito_breeding_sites            39000 non-null int32
# stagnant_waters                    39000 non-null int32
# iot_air_quality                    39000 non-null int32
# iot_water_quality                  39000 non-null int32
# presence_of_vegetation             39000 non-null int32
# outbreak_threshold                 39000 non-null float64
# dtypes: float64(1), int32(17)
# memory usage: 3.1 MB

# %%
X = df.drop(columns=['outbreak_threshold'])
y=df['outbreak_threshold']

# %%
y
# Out:
# 7270    0.668590
# 7603    0.746953
# 860     0.732301
# 5390    0.097194
# 5226    0.621262
#           ...
# 6222    0.675697
# 5107    0.857199
# 2017    0.106984
# 4223    0.621336
# 4508    0.512871
# Name: outbreak_threshold, Length: 39000, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)

# %%
X_train
# Out:
#       temp_level  humidity  precipitation  frequency_outbreak_in_area  \
# 65             1         0              0                           0
# 5757           0         0              1                           0
# 6324           1         1              0                           1
# 7518           1         1              1                           0
# 5392           0         1              0                           1
# ...          ...       ...            ...                         ...
# 972            1         1              1                           0
# 2549           0         0              1                           1
# 5039           0         0              1                           1
# 2871           0         1              0                           0
# 5336           0         1              1                           1
#
#       travel_patterns  mosquito_species  malaria_vectors  \
# 65                  1                 0                0
# 5757                0                 1                1
# 6324                0                 1                1
# 7518                1                 1                0
# 5392                1                 1                1
# ...               ...               ...              ...
# 972                 0                 0                1
# 2549                1                 2                1
# 5039                1                 1                1
# 2871                0                 1                1
# 5336                0                 1                1
#
#       vectors_infection_rates  healthcare_availability  \
# 65                          1                        0
# 5757                        0                        0
# 6324                        1                        0
# 7518                        0                        1
# 5392                        0                        1
# ...                       ...                      ...
# 972                         0                        1
# 2549                        0                        0
# 5039                        1                        1
# 2871                        0                        0
# 5336                        1                        1
#
#       healthcare_accessibility  malaria_treatment_success_rates  land_use  \
# 65                           1                                0         1
# 5757                         0                                0         1
# 6324                         0                                1         1
# 7518                         0                                1         0
# 5392                         1                                0         1
# ...                        ...                              ...       ...
# 972                          1                                0         0
# 2549                         0                                1         0
# 5039                         1                                0         1
# 2871                         1                                0         0
# 5336                         0                                0         0
#
#       mosquito_breeding_sites  stagnant_waters  iot_air_quality  \
# 65                          1                0                0
# 5757                        1                0                0
# 6324                        1                0                0
# 7518                        1                0                0
# 5392                        0                1                1
# ...                       ...              ...              ...
# 972                         1                0                0
# 2549                        0                1                0
# 5039                        1                0                1
# 2871                        1                0                1
# 5336                        1                1                0
#
#       iot_water_quality  presence_of_vegetation
# 65                    1                       1
# 5757                  0                       1
# 6324                  0                       1
# 7518                  1                       1
# 5392                  0                       1
# ...                 ...                     ...
# 972                   0                       1
# 2549                  1                       0
# 5039                  1                       0
# 2871                  0                       0
# 5336                  1                       1
#
# [31200 rows x 17 columns]

# %%
X_test
# Out:
#       temp_level  humidity  precipitation  frequency_outbreak_in_area  \
# 7173           1         0              0                           0
# 176            0         1              1                           1
# 1046           1         0              1                           1
# 3772           1         1              0                           0
# 7433           0         1              1                           0
# ...          ...       ...            ...                         ...
# 1391           1         1              0                           1
# 1454           0         0              1                           0
# 3941           1         1              0                           1
# 4686           1         0              0                           0
# 7526           0         0              1                           1
#
#       travel_patterns  mosquito_species  malaria_vectors  \
# 7173                0                 0                0
# 176                 0                 1                0
# 1046                0                 0                0
# 3772                1                 1                1
# 7433                0                 1                1
# ...               ...               ...              ...
# 1391                0                 1                1
# 1454                1                 0                1
# 3941                0                 0                0
# 4686                1                 0                1
# 7526                0                 1                1
#
#       vectors_infection_rates  healthcare_availability  \
# 7173                        1                        0
# 176                         0                        1
# 1046                        0                        0
# 3772                        1                        0
# 7433                        1                        0
# ...                       ...                      ...
# 1391                        0                        1
# 1454                        1                        1
# 3941                        0                        0
# 4686                        1                        1
# 7526                        0                        0
#
#       healthcare_accessibility  malaria_treatment_success_rates  land_use  \
# 7173                         0                                1         1
# 176                          0                                1         0
# 1046                         1                                1         0
# 3772                         1                                0         1
# 7433                         0                                1         0
# ...                        ...                              ...       ...
# 1391                         1                                1         1
# 1454                         1                                0         1
# 3941                         0                                1         0
# 4686                         1                                0         0
# 7526                         0                                1         0
#
#       mosquito_breeding_sites  stagnant_waters  iot_air_quality  \
# 7173                        0                0                1
# 176                         1                0                1
# 1046                        0                0                0
# 3772                        0                0                0
# 7433                        1                0                0
# ...                       ...              ...              ...
# 1391                        1                1                0
# 1454                        0                0                0
# 3941                        0                0                0
# 4686                        0                0                0
# 7526                        0                1                1
#
#       iot_water_quality  presence_of_vegetation
# 7173                  1                       0
# 176                   0                       1
# 1046                  0                       0
# 3772                  1                       1
# 7433                  0                       1
# ...                 ...                     ...
# 1391                  1                       1
# 1454                  0                       1
# 3941                  1                       1
# 4686                  1                       0
# 7526                  1                       1
#
# [7800 rows x 17 columns]

# %%
y_train
# Out:
# 65      0.028758
# 5757    0.516933
# 6324    0.380070
# 7518    0.191926
# 5392    0.507628
#           ...
# 972     0.224001
# 2549    0.777981
# 5039    0.982045
# 2871    0.502747
# 5336    0.735319
# Name: outbreak_threshold, Length: 31200, dtype: float64

# %%
y_test_1=y_test.head(48)
y_test_1
# Out:
# 7173    0.534346
# 176     0.201702
# 1046    0.351270
# 3772    0.355786
# 7433    0.458929
# 7946    0.308928
# 1625    0.153921
# 2118    0.317449
# 7292    0.495835
# 2909    0.854292
# 4415    0.480247
# 1677    0.209497
# 4993    0.522328
# 7050    0.711318
# 7665    0.086700
# 2198    0.530088
# 296     0.763751
# 319     0.760314
# 3612    0.876884
# 7995    0.730745
# 3272    0.203864
# 1862    0.068206
# 1126    0.043498
# 1316    0.236461
# 767     0.687873
# 4718    0.525605
# 1636    0.020704
# 5335    0.753589
# 3560    0.244439
# 1315    0.050791
# 7878    0.509128
# 6235    0.684746
# 2295    0.459705
# 6614    0.553676
# 4567    0.202878
# 2403    0.062654
# 3717    0.217128
# 7456    0.853124
# 6622    0.481510
# 1160    0.320299
# 7290    0.422258
# 2842    0.538491
# 2895    0.862614
# 3697    0.460206
# 6793    0.651229
# 7398    0.783965
# 7552    0.249907
# 1855    0.100893
# Name: outbreak_threshold, dtype: float64

# %%
df.head(2)
# Out:
#       temp_level  humidity  precipitation  frequency_outbreak_in_area  \
# 7270           1         1              1                           0
# 7603           0         1              0                           0
#
#       travel_patterns  mosquito_species  malaria_vectors  \
# 7270                1                 1                0
# 7603                0                 2                1
#
#       vectors_infection_rates  healthcare_availability  \
# 7270                        0                        0
# 7603                        0                        0
#
#       healthcare_accessibility  malaria_treatment_success_rates  land_use  \
# 7270                         0                                0         1
# 7603                         0                                0         1
#
#       mosquito_breeding_sites  stagnant_waters  iot_air_quality  \
# 7270                        1                0                0
# 7603                        1                0                0
#
#       iot_water_quality  presence_of_vegetation  outbreak_threshold
# 7270                  1                       0            0.668590
# 7603                  0                       1            0.746953

# %%
plt.figure(figsize = (25,10))
ax = sns.barplot(x="mosquito_species", y= "outbreak_threshold", data=df[:18] ,palette = "Spectral")
plt.title (" Number outbreak_threshold")
plt.xticks(rotation = 60, ha = 'right')
plt.xlabel("mosquito_species")
plt.ylabel("outbreak_threshold")

plt.show()

# %%
df['mosquito_species']
# Out:
# 7270    1
# 7603    2
# 860     1
# 5390    0
# 5226    1
#        ..
# 6222    0
# 5107    0
# 2017    0
# 4223    1
# 4508    1
# Name: mosquito_species, Length: 39000, dtype: int32

# %%
y_test
# Out:
# 7173    0.534346
# 176     0.201702
# 1046    0.351270
# 3772    0.355786
# 7433    0.458929
#           ...
# 1391    0.110123
# 1454    0.418450
# 3941    0.257418
# 4686    0.328211
# 7526    0.666757
# Name: outbreak_threshold, Length: 7800, dtype: float64

# %%
#function to calculate various metrics such as accuracy, precision etc
def calculateMetrics(algorithm, predict, testY):
    testY = testY.astype('int')
    predict = predict.astype('int')
    mse = mean_squared_error(testY, predict)
    mae = mean_absolute_error(testY, predict)
    r2 = r2_score(testY, predict) * 100
    
    mean_squared_error.append(mse)
    mean_absolute_error.append(mae)
    r2_score.append(r2)
    
    print(algorithm+' Accuracy    : '+str(a))
    print(algorithm+' Precision   : '+str(p))
    print(algorithm+' Recall      : '+str(r))
    print(algorithm+' FSCORE      : '+str(f))
    report=classification_report(predict, testY,target_names=labels)
    print('\n',algorithm+" classification report\n",report)
    conf_matrix = confusion_matrix(testY, predict) 
    plt.figure(figsize =(5, 5)) 
    ax = sns.heatmap(conf_matrix, xticklabels = labels, yticklabels = labels, annot = True, cmap="Blues" ,fmt ="g");
    ax.set_ylim([0,len(labels)])
    plt.title(algorithm+" Confusion matrix") 
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %% [markdown]
# ## Decision Tree

# %%
import os
import joblib
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Example function to calculate metrics (you can modify it as needed)
def calculate_metrics(model_name, y_pred, y_test):
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{model_name} Metrics:")
    print(f"Mean Squared Error: {mse}")
    print(f"R^2 Score: {r2}")

# Check if the model file exists
if os.path.exists('Decision_tree_regressor_model.pkl'):
    # Load the trained model from the file
    reg = joblib.load('Decision_tree_regressor_model.pkl')
    print("Model loaded successfully.")
    y_pred = reg.predict(X_test)
    calculate_metrics("DecisionTreeRegressor", y_pred, y_test)
else:
    # Train the model (assuming X_train and y_train are defined)
    reg = DecisionTreeRegressor(max_depth=10, random_state=0)
    reg.fit(X_train, y_train)
    # Save the trained model to a file
    joblib.dump(reg, 'Decision_tree_regressor_model.pkl')
    print("Model saved successfully.")
    y_pred = reg.predict(X_test)
    calculate_metrics("DecisionTreeRegressor", y_pred, y_test)
# Out:
# Model loaded successfully.
# DecisionTreeRegressor Metrics:
# Mean Squared Error: 0.05933887470037644
# R^2 Score: 0.28436763066559867

# %% [markdown]
# ## MLP

# %%
import os
import joblib
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Example function to calculate metrics (you can modify it as needed)
def calculate_metrics(model_name, y_pred, y_test):
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{model_name} Metrics:")
    print(f"Mean Squared Error: {mse}")
    print(f"R^2 Score: {r2}")

# Check if the model file exists
if os.path.exists('MLP_regressor_model.pkl'):
    # Load the trained model from the file
    reg = joblib.load('MLP_regressor_model.pkl')
    print("Model loaded successfully.")
    y_pred = reg.predict(X_test)
    calculate_metrics("MLPRegressor", y_pred, y_test)
else:
    # Train the model (assuming X_train and y_train are defined)
    reg = MLPRegressor(hidden_layer_sizes=(180, 180), max_iter=1000, random_state=0)
    reg.fit(X_train, y_train)
    # Save the trained model to a file
    joblib.dump(reg, 'MLP_regressor_model.pkl')
    print("Model saved successfully.")
    y_pred = reg.predict(X_test)
    calculate_metrics("MLPRegressor", y_pred, y_test)
# Out:
# Model loaded successfully.
# MLPRegressor Metrics:
# Mean Squared Error: 0.00792599189166396
# R^2 Score: 0.9044117977397244

# %% [markdown]
# ## test data

# %%
test=pd.read_csv(r'test.csv')
test.head()
# Out:
#   temp_level humidity precipitation frequency_outbreak_in_area  \
# 0        Low     High           Yes                       High
# 1       High      Low            No                       High
# 2       High     High           Yes                        Low
# 3       High      Low           Yes                        Low
# 4        Low     High           Yes                       High
#
#   travel_patterns        mosquito_species malaria_vectors  \
# 0             Low           Aedes aegypti              No
# 1            High       Anopheles gambiae              No
# 2            High  Culex quinquefasciatus              No
# 3             Low       Anopheles gambiae             Yes
# 4             Low           Aedes aegypti             Yes
#
#   vectors_infection_rates healthcare_availability healthcare_accessibility  \
# 0                     Low                     Yes                       No
# 1                    High                     Yes                      Yes
# 2                     Low                     Yes                      Yes
# 3                     Low                      No                      Yes
# 4                     Low                      No                      Yes
#
#   malaria_treatment_success_rates land_use mosquito_breeding_sites  \
# 0                             Low    Urban                      No
# 1                            High    Urban                     Yes
# 2                            High    Urban                     Yes
# 3                             Low    Rural                     Yes
# 4                             Low    Urban                      No
#
#   stagnant_waters iot_air_quality iot_water_quality presence_of_vegetation
# 0             Yes             Bad              Good                    Yes
# 1             Yes             Bad               Bad                    Yes
# 2             Yes             Bad              Good                     No
# 3             Yes            Good              Good                    Yes
# 4             Yes             Bad              Good                     No

# %%
# Initialize the LabelEncoder
le= LabelEncoder()

# Loop through each column in the DataFrame
for column in test.columns:
    if test[column].dtype == 'object':
        test[column] = le.fit_transform(test[column])
df.head()
# Out:
#       temp_level  humidity  precipitation  frequency_outbreak_in_area  \
# 7270           1         1              1                           0
# 7603           0         1              0                           0
# 860            0         1              1                           1
# 5390           1         0              0                           1
# 5226           1         0              0                           0
#
#       travel_patterns  mosquito_species  malaria_vectors  \
# 7270                1                 1                0
# 7603                0                 2                1
# 860                 0                 1                0
# 5390                1                 0                0
# 5226                0                 1                1
#
#       vectors_infection_rates  healthcare_availability  \
# 7270                        0                        0
# 7603                        0                        0
# 860                         0                        0
# 5390                        1                        1
# 5226                        0                        0
#
#       healthcare_accessibility  malaria_treatment_success_rates  land_use  \
# 7270                         0                                0         1
# 7603                         0                                0         1
# 860                          1                                1         1
# 5390                         0                                1         0
# 5226                         1                                1         0
#
#       mosquito_breeding_sites  stagnant_waters  iot_air_quality  \
# 7270                        1                0                0
# 7603                        1                0                0
# 860                         1                1                1
# 5390                        1                1                1
# 5226                        1                0                1
#
#       iot_water_quality  presence_of_vegetation  outbreak_threshold
# 7270                  1                       0            0.668590
# 7603                  0                       1            0.746953
# 860                   0                       0            0.732301
# 5390                  0                       0            0.097194
# 5226                  0                       0            0.621262

# %%
X_test.shape
# Out:
# (7800, 17)

# %%
test.shape
# Out:
# (49, 17)

# %%
# Make predictions on the selected test data
predict = reg.predict(test)
predict
# Out:
# array([0.45231423, 0.02738364, 0.93328293, 0.85075121, 0.37698174,
#        0.38825649, 0.89521031, 0.59078525, 0.87553901, 0.13496217,
#        0.76358978, 0.96520282, 1.00786206, 0.91652966, 0.87440767,
#        0.35391502, 0.9163284 , 0.38818299, 0.5760562 , 0.88208268,
#        0.67526277, 0.18166429, 0.2289708 , 0.58020606, 0.39737878,
#        0.21994445, 0.29590304, 0.56589181, 0.2262419 , 0.52125727,
#        0.1420797 , 0.62552018, 0.35833852, 0.75062995, 0.72426147,
#        0.32549496, 0.9800958 , 0.35548548, 0.20563633, 0.24948601,
#        0.21989428, 0.24045385, 0.33156197, 0.46800931, 0.20001072,
#        0.06228014, 0.08775024, 0.83546641, 0.68444189])

# %%
predict
# Out:
# array([0.45231423, 0.02738364, 0.93328293, 0.85075121, 0.37698174,
#        0.38825649, 0.89521031, 0.59078525, 0.87553901, 0.13496217,
#        0.76358978, 0.96520282, 1.00786206, 0.91652966, 0.87440767,
#        0.35391502, 0.9163284 , 0.38818299, 0.5760562 , 0.88208268,
#        0.67526277, 0.18166429, 0.2289708 , 0.58020606, 0.39737878,
#        0.21994445, 0.29590304, 0.56589181, 0.2262419 , 0.52125727,
#        0.1420797 , 0.62552018, 0.35833852, 0.75062995, 0.72426147,
#        0.32549496, 0.9800958 , 0.35548548, 0.20563633, 0.24948601,
#        0.21989428, 0.24045385, 0.33156197, 0.46800931, 0.20001072,
#        0.06228014, 0.08775024, 0.83546641, 0.68444189])

# %%
predict=pd.DataFrame(predict)
predict.head()
# Out:
#           0
# 0  0.452314
# 1  0.027384
# 2  0.933283
# 3  0.850751
# 4  0.376982

# %%
test=pd.read_csv(r'test.csv')
test.head()
# Out:
#   temp_level humidity precipitation frequency_outbreak_in_area  \
# 0        Low     High           Yes                       High
# 1       High      Low            No                       High
# 2       High     High           Yes                        Low
# 3       High      Low           Yes                        Low
# 4        Low     High           Yes                       High
#
#   travel_patterns        mosquito_species malaria_vectors  \
# 0             Low           Aedes aegypti              No
# 1            High       Anopheles gambiae              No
# 2            High  Culex quinquefasciatus              No
# 3             Low       Anopheles gambiae             Yes
# 4             Low           Aedes aegypti             Yes
#
#   vectors_infection_rates healthcare_availability healthcare_accessibility  \
# 0                     Low                     Yes                       No
# 1                    High                     Yes                      Yes
# 2                     Low                     Yes                      Yes
# 3                     Low                      No                      Yes
# 4                     Low                      No                      Yes
#
#   malaria_treatment_success_rates land_use mosquito_breeding_sites  \
# 0                             Low    Urban                      No
# 1                            High    Urban                     Yes
# 2                            High    Urban                     Yes
# 3                             Low    Rural                     Yes
# 4                             Low    Urban                      No
#
#   stagnant_waters iot_air_quality iot_water_quality presence_of_vegetation
# 0             Yes             Bad              Good                    Yes
# 1             Yes             Bad               Bad                    Yes
# 2             Yes             Bad              Good                     No
# 3             Yes            Good              Good                    Yes
# 4             Yes             Bad              Good                     No

# %%
test['predict']=predict
test.head()
# Out:
#   temp_level humidity precipitation frequency_outbreak_in_area  \
# 0        Low     High           Yes                       High
# 1       High      Low            No                       High
# 2       High     High           Yes                        Low
# 3       High      Low           Yes                        Low
# 4        Low     High           Yes                       High
#
#   travel_patterns        mosquito_species malaria_vectors  \
# 0             Low           Aedes aegypti              No
# 1            High       Anopheles gambiae              No
# 2            High  Culex quinquefasciatus              No
# 3             Low       Anopheles gambiae             Yes
# 4             Low           Aedes aegypti             Yes
#
#   vectors_infection_rates healthcare_availability healthcare_accessibility  \
# 0                     Low                     Yes                       No
# 1                    High                     Yes                      Yes
# 2                     Low                     Yes                      Yes
# 3                     Low                      No                      Yes
# 4                     Low                      No                      Yes
#
#   malaria_treatment_success_rates land_use mosquito_breeding_sites  \
# 0                             Low    Urban                      No
# 1                            High    Urban                     Yes
# 2                            High    Urban                     Yes
# 3                             Low    Rural                     Yes
# 4                             Low    Urban                      No
#
#   stagnant_waters iot_air_quality iot_water_quality presence_of_vegetation  \
# 0             Yes             Bad              Good                    Yes
# 1             Yes             Bad               Bad                    Yes
# 2             Yes             Bad              Good                     No
# 3             Yes            Good              Good                    Yes
# 4             Yes             Bad              Good                     No
#
#     predict
# 0  0.452314
# 1  0.027384
# 2  0.933283
# 3  0.850751
# 4  0.376982
